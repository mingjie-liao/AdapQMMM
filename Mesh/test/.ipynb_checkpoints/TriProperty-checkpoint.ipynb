# %%
;pwd
# Out:
# /Users/Edgar/Program/Julia/AdapQMMM/Mesh/test

# %%
using PyPlot

# %%
include("../src/readmesh.jl")

vex, edg_g, tri = read_mesh("QMMMball.mesh")
nothing

# %%
trit = tri[1:3, :]';

# %%
PyPlot.triplot(vex[1,:], vex[2,:], trit-1)
axis("equal")
nothing
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320acc358>)

# %%
nT = size(trit,1)
# Out:
# 2559

# %%
include("../develop/triProperty.jl")
# Out:
# mesh_incenter_maxh_area (generic function with 1 method)

# %%
Incenter, MaxH, Area = mesh_incenter_maxh_area(vex, trit);

# %%
PyPlot.triplot(vex[1,:], vex[2,:], trit-1)
PyPlot.plot(Incenter[1,:], Incenter[2,:], "go")
axis("equal")
nothing
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32bdc22e8>)

# %%
n = rand(1:44)
println("Area of element: $n = $(Area[n])")
x = vex[1,trit[n,:]]
y = vex[2,trit[n,:]]
s = det([x y [1;1;1]])/2
println("Area by deter")
# Out:
# Area of element: 26 = 0.2964837358102699
# Area by d
