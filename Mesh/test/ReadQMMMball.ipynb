# %% [markdown]
# # Read QMMMball.mesh. Return vex, edg_g, tri and plot

# %%
using PyPlot

# %%
include("../src/readmesh.jl")
# Out:
# read_mesh

# %%
vex, edg_g, tri = read_mesh("QMMMball.mesh");

# %%
trit = tri[1:3,:]'
# Out:
# 2559×3 Array{Int64,2}:
#   376   375   448
#   375   302   301
#   374   375   301
#   449   448   375
#   376   324   302
#   450   376   448
#   450   471   396
#   390   391   466
#   465   390   466
#   321   317   390
#   258   262   319
#   318   258   319
#   205   208   258
#     ⋮
#  1252  1278  1253
#  1275  1274  1248
#  1289  1275  1276
#  1289  1274  1275
#  1276  1251  1250
#  1276  1249  1251
#  1275  1248  1249
#  1289  1293  1292
#  1274  1289  1287
#  1247  1274  1246
#  1247  1248  1274
#  1276  1275  1249

# %%
trit = trit-1; # the third argument of PyPlot.triplot start indexing from 0..

# %%
PyPlot.triplot(vex[1,:], vex[2,:], trit)
axis("equal")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x32239a278>)
# (-87.33763491046,87.96845880526,-87.82635210173,87.82635210173)
